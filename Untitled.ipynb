# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from tensorflow.keras import models
from tensorflow.keras import layers

# %%
PAMP = pd.read_csv('./Data/Argentina - Pampa Energia SA (PAMP).csv')
BEEF = pd.read_csv('./Data/Brazil - Minerva SA_Brazil (BEEF3).csv')
CCB = pd.read_csv('./Data/Colombia - Cementos Argos SA (CCB).csv')
MNHD = pd.read_csv('./Data/Egypt - Medinet Nasr Housing (MNHD).csv')
SBER = pd.read_csv('./Data/Russia - Sberbank Rossii PAO (SBER).csv')
IMPJ = pd.read_csv('./Data/South Africa - Impala Platinum Holdings Ltd (IMPJ).csv')
DSMC = pd.read_csv('./Data/South Korea - Dongkuk Steel Mill Co Ltd (001230).csv')
KCHOL = pd.read_csv('./Data/Turkey - Koc Holding AS (KCHOL).csv')

# %%
PAMP
# Out:
#                 Date           Price                Open             High  \
# 0       Mar 31, 2021           85.15                86.5             88.1
# 1       Mar 30, 2021            86.1               85.15            86.75
# 2       Mar 29, 2021              85                  80               86
# 3       Mar 26, 2021           81.85                  84             84.6
# 4       Mar 25, 2021            83.6                85.2             87.3
# ..               ...             ...                 ...              ...
# 296     Jan 07, 2020            47.6               48.35               49
# 297     Jan 06, 2020            48.5                48.4             48.7
# 298     Jan 03, 2020            48.8               48.25            49.45
# 299     Jan 02, 2020           48.25               49.35             50.2
# 300  Highest: 90.000  Lowest: 32.000  Difference: 58.000  Average: 61.244
#
#                   Low     Vol. Change %
# 0               85.15  564.30K   -1.10%
# 1                84.6  141.40K    1.29%
# 2                  79  371.22K    3.85%
# 3                80.7  462.55K   -2.09%
# 4                82.1  389.78K   -3.13%
# ..                ...      ...      ...
# 296              46.9  901.95K   -1.86%
# 297                47  719.24K   -0.61%
# 298              46.5  595.36K    1.14%
# 299             47.55  878.50K   -2.92%
# 300  Change %: 71.328      NaN      NaN
#
# [301 rows x 7 columns]

# %%
PAMP.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      301 non-null    object
#  1   Price     301 non-null    object
#  2   Open      301 non-null    object
#  3   High      301 non-null    object
#  4   Low       301 non-null    object
#  5   Vol.      300 non-null    object
#  6   Change %  300 non-null    object
# dtypes: object(7)
# memory usage: 16.6+ KB

# %%
## drop last row because it doesn't contain relevant information

PAMP.drop(300, inplace=True)

# %%
## change date column to datetime

PAMP['Date'] = pd.to_datetime(PAMP['Date'], format='%b %d, %Y')

# %%
## change price columns to integer

PAMP['Price'] = pd.to_numeric(PAMP['Price'])
PAMP['Open'] = pd.to_numeric(PAMP['Open'])
PAMP['High'] = pd.to_numeric(PAMP['High'])
PAMP['Low'] = pd.to_numeric(PAMP['Low'])

# %%
PAMP.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 300 entries, 0 to 299
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      300 non-null    datetime64[ns]
#  1   Price     300 non-null    float64
#  2   Open      300 non-null    float64
#  3   High      300 non-null    float64
#  4   Low       300 non-null    float64
#  5   Vol.      300 non-null    object
#  6   Change %  300 non-null    object
# dtypes: datetime64[ns](1), float64(4), object(2)
# memory usage:
# %%
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(PAMP[['Price']])
scaled_train_data = scaled_data[:240]

# %%
X_train, y_train = get_train_data(scaled_train_data, 10)

# %%
inputs = tf.keras.Input(shape=(X_train.shape[1], 1))
x = layers.LSTM(units=50, return_sequences=True)(inputs)
x = layers.Dropout(0.2)(x)
x = layers.LSTM(units=50)(x)
x = layers.Dropout(0.2)(x)
output = layers.Dense(1, activation='linear')(x)

model = tf.keras.Model(inputs=inputs, outputs=output)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 10, 1)]           0
#
#  lstm (LSTM)                 (None, 10, 50)            10400
#
#  dropout (Dropout)           (None, 10, 50)            0
#
#  lstm_1 (LSTM)               (None, 50)                20200
#
#  dropout_1 (Dropout)         (None, 50)                0
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 30,651
# Trainable params: 30,651
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='mean_squared_error', 
              optimizer=tf.keras.optimizers.Adam(lr=.01, decay=0.01))

history = model.fit(X_train, y_train, epochs=200)
# Out:
# C:\Users\Chris\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Epoch 1/200
# 8/8 [==============================] - 3s 10ms/step - loss: 0.0998
# Epoch 2/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0357
# Epoch 3/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0203
# Epoch 4/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0103
# Epoch 5/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0080
# Epoch 6/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0064
# Epoch 7/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0096
# Epoch 8/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0064
# Epoch 9/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0053
# Epoch 10/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0058
# Epoch 11/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0049
# Epoch 12/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0051
# Epoch 13/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0058
# Epoch 14/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0063
# Epoch 15/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0055
# Epoch 16/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0056
# Epoch 17/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0053
# Epoch 18/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0048
# Epoch 19/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0057
# Epoch 20/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0053
# Epoch 21/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0049
# Epoch 22/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0050
# Epoch 23/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0053
# Epoch 24/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0052
# Epoch 25/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0056
# Epoch 26/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0051
# Epoch 27/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0046
# Epoch 28/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0051
# Epoch 29/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0045
# Epoch 30/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0053
# Epoch 31/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0056
# Epoch 32/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0046
# Epoch 33/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0050
# Epoch 34/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0045
# Epoch 35/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0045
# Epoch 36/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0044
# Epoch 37/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0045
# Epoch 38/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0046
# Epoch 39/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0045
# Epoch 40/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0046
# Epoch 41/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0040
# Epoch 42/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0038
# Epoch 43/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0049
# Epoch 44/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0037
# Epoch 45/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0041
# Epoch 46/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0041
# Epoch 47/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0044
# Epoch 48/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0041
# Epoch 49/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0045
# Epoch 50/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0034
# Epoch 51/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0036
# Epoch 52/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0038
# Epoch 53/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0036
# Epoch 54/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0035
# Epoch 55/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0036
# Epoch 56/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0041
# Epoch 57/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0042
# Epoch 58/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0035
# Epoch 59/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0035
# Epoch 60/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0032
# Epoch 61/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0038
# Epoch 62/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0035
# Epoch 63/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0037
# Epoch 64/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0036
# Epoch 65/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0041
# Epoch 66/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0041
# Epoch 67/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0036
# Epoch 68/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0035
# Epoch 69/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0041
# Epoch 70/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0039
# Epoch 71/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0038
# Epoch 72/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0033
# Epoch 73/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0038
# Epoch 74/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0037
# Epoch 75/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0051
# Epoch 76/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0044
# Epoch 77/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0036
# Epoch 78/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0041
# Epoch 79/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0036
# Epoch 80/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0034
# Epoch 81/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0039
# Epoch 82/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0031
# Epoch 83/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0041
# Epoch 84/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0032
# Epoch 85/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0037
# Epoch 86/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0041
# Epoch 87/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0036
# Epoch 88/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0034
# Epoch 89/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0033
# Epoch 90/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0034
# Epoch 91/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0033
# Epoch 92/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0033
# Epoch 93/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0030
# Epoch 94/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0040
# Epoch 95/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0035
# Epoch 96/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0033
# Epoch 97/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0031
# Epoch 98/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0036
# Epoch 99/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0035
# Epoch 100/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0033
# Epoch 101/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0029
# Epoch 102/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0038
# Epoch 103/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0030
# Epoch 104/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0030
# Epoch 105/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0037
# Epoch 106/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0030
# Epoch 107/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0038
# Epoch 108/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0031
# Epoch 109/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0028
# Epoch 110/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0030
# Epoch 111/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0035
# Epoch 112/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0028
# Epoch 113/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0033
# Epoch 114/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0034
# Epoch 115/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0036
# Epoch 116/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0029
# Epoch 117/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0029
# Epoch 118/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0030
# Epoch 119/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0033
# Epoch 120/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0031
# Epoch 121/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0029
# Epoch 122/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0035
# Epoch 123/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0032
# Epoch 124/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0031
# Epoch 125/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0032
# Epoch 126/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0032
# Epoch 127/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0027
# Epoch 128/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0028
# Epoch 129/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0028
# Epoch 130/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0028
# Epoch 131/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0028
# Epoch 132/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0029
# Epoch 133/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0033
# Epoch 134/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0028
# Epoch 135/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0028
# Epoch 136/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0029
# Epoch 137/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0026
# Epoch 138/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0031
# Epoch 139/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0028
# Epoch 140/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0030
# Epoch 141/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0024
# Epoch 142/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0030
# Epoch 143/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0029
# Epoch 144/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0027
# Epoch 145/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0027
# Epoch 146/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0035
# Epoch 147/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0030
# Epoch 148/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0032
# Epoch 149/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0033
# Epoch 150/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0026
# Epoch 151/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0032
# Epoch 152/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0023
# Epoch 153/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0027
# Epoch 154/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0027
# Epoch 155/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0024
# Epoch 156/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0029
# Epoch 157/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0030
# Epoch 158/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0031
# Epoch 159/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0032
# Epoch 160/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0033
# Epoch 161/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0027
# Epoch 162/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0029
# Epoch 163/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0027
# Epoch 164/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0029
# Epoch 165/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0029
# Epoch 166/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0033
# Epoch 167/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0035
# Epoch 168/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0030
# Epoch 169/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0027
# Epoch 170/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0029
# Epoch 171/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0031
# Epoch 172/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0030
# Epoch 173/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0025
# Epoch 174/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0029
# Epoch 175/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0030
# Epoch 176/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0027
# Epoch 177/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0030
# Epoch 178/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0024
# Epoch 179/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0025
# Epoch 180/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0029
# Epoch 181/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0028
# Epoch 182/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0022
# Epoch 183/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0030
# Epoch 184/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0028
# Epoch 185/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0025
# Epoch 186/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0029
# Epoch 187/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0028
# Epoch 188/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0028
# Epoch 189/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0026
# Epoch 190/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0031
# Epoch 191/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0031
# Epoch 192/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0027
# Epoch 193/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0032
# Epoch 194/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0027
# Epoch 195/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0026
# Epoch 196/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0032
# Epoch 197/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0024
# Epoch 198/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0022
# Epoch 199/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0027
# Epoch 200/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0026

# %%
plt.figure(figsize=(10, 8))
plt.plot(history.history['loss'], label='training loss')

# %%
def get_test_data(data, scaler, window_size):
    raw = data['Price'][len(data) - len(testing_data) - window_size:].values
    raw = raw.reshape(-1, 1)
    raw = scaler.transform(raw)
    
    X_test = []
    
    for i in range(window_size, raw.shape[0]):
        X_test.append(raw[i-window_size:i, 0])
        
    X_test = np.array(X_test)
    
    X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
    
    return X_test

# %%
X_test = get_test_data(PAMP, scaler, 10)

# %%
pred_price = model.predict(X_test)
pred_price = scaler.inverse_transform(pred_price)
testing_data['Predicted_Price'] = pred_price

# %%
plt.figure(figsize=(20, 10))

plt.plot(training_data['Date'], training_data['Price'], label='Training Price')
plt.plot(testing_data['Date'], testing_data['Price'], label='Testing Data')
plt.plot(testing_data['Date'], testing_data['Predicted_Price'], label='Predicted Price')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('PAMP Stock Price')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 10))
plt.plot(testing_data['Date'], testing_data['Price'], label='Closing Price')
plt.plot(testing_data['Date'], testing_data['Predicted_Price'], label='Predicted Price')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Price of PAMP in 2021')
plt.legend()
plt.show()

# %% [markdown]
# Either have an output for the 7 days of the week or have an output and use previous day's prediction as well

# %% [markdown]
# ## PyTorch

# %%
import torch
import torch.nn as nn

# %%
def split_data(stock, lookback):
    data_raw = stock.to_numpy() # convert to numpy array
    data = []
    
    # create all possible sequences of length seq_len
    for index in range(len(data_raw) - lookback): 
        data.append(data_raw[index: index + lookback])

    data = np.array(data)
    test_set_size = 60
    train_set_size = data.shape[0] - (test_set_size)
    
    x_train = data[:train_set_size,:-1,:]
    y_train = data[:train_set_size,-1,:]
    
    x_test = data[train_set_size:,:-1]
    y_test = data[train_set_size:,-1,:]
    
    return [x_train, y_train, x_test, y_test]

# %%
price = PAMP[['Price']]
price['Price'] = scaler.transform(price['Price'].values.reshape(-1, 1))
price
# Out:
# C:\Users\Chris\AppData\Local\Temp/ipykernel_17952/3439380683.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   price['Price'] = scaler.transform(price['Price'].values.reshape(-1, 1))
#         Price
# 0    0.272809
# 1    0.282648
# 2    0.277281
# 3    0.261181
# 4    0.241503
# ..        ...
# 295  0.905188
# 296  0.873882
# 297  0.930233
# 298  0.949911
# 299  0.932916
#
# [300 rows x 1 columns]

# %%
X_train, y_train, X_test, y_test = split_data(price, 14)

# %%
X_train = torch.from_numpy(X_train).type(torch.Tensor)
X_test = torch.from_numpy(X_test).type(torch.Tensor)
y_train = torch.from_numpy(y_train).type(torch.Tensor)
y_test = torch.from_numpy(y_test).type(torch.Tensor)

# %%
class LSTM(nn.Module):
    def __init__(self, input_dim, hidden_dim, num_layers, output_dim):
        super(LSTM, self).__init__()
        self.hidden_dim = hidden_dim
        self.num_layers = num_layers
        
        self.lstm = nn.LSTM(input_dim, hidden_dim, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_dim, output_dim)   
        
    def forward(self, x):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_dim).requires_grad_()
        c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_dim).requires_grad_()
        out, (hn, cn) = self.lstm(x, (h0.detach(), c0.detach()))
        out = self.fc(out[:, -1, :]) 
        return out

# %%
model = LSTM(input_dim=1, hidden_dim=32, output_dim=1, num_layers=2)
criterion = torch.nn.MSELoss(reduction='mean')
optimiser = torch.optim.Adam(model.parameters(), lr=0.01)

# %%
num_epochs = 200

hist = np.zeros(num_epochs)
lstm = []
for t in range(num_epochs):
    y_train_pred = model(X_train)    
    
    loss = criterion(y_train_pred, y_train)
    print("Epoch ", t, "MSE: ", loss.item())
    hist[t] = loss.item()    
    
    optimiser.zero_grad()
    loss.backward()
    optimiser.step()
# Out:
# Epoch  0 MSE:  0.24503734707832336
# Epoch  1 MSE:  0.15524408221244812
# Epoch  2 MSE:  0.08718868345022202
# Epoch  3 MSE:  0.055666565895080566
# Epoch  4 MSE:  0.10300657153129578
# Epoch  5 MSE:  0.06256331503391266
# Epoch  6 MSE:  0.050824057310819626
# Epoch  7 MSE:  0.05550253763794899
# Epoch  8 MSE:  0.06052887439727783
# Epoch  9 MSE:  0.061075516045093536
# Epoch  10 MSE:  0.056578900665044785
# Epoch  11 MSE:  0.0477420836687088
# Epoch  12 MSE:  0.036414533853530884
# Epoch  13 MSE:  0.028291061520576477
# Epoch  14 MSE:  0.0352405346930027
# Epoch  15 MSE:  0.03355429321527481
# Epoch  144 MSE:  0.002223932882770896
# Epoch  145 MSE:  0.0022047171369194984
# Epoch  146 MSE:  0.0021853207144886255
# Epoch  147 MSE:  0.002165811834856868
# Epoch  148 MSE:  0.0021462752483785152
# Epoch  149 MSE:  0.00212672702036798
# Epoch  150 MSE:  0.002107241889461875
# Epoch  151 MSE:  0.0020878082141280174
# Epoch  152 MSE:  0.0020684886258095503
# Epoch  153 MSE:  0.002049387199804187
# Epoch  154 MSE:  0.0020305432844907045
# Epoch  155 MSE:  0.0020120239350944757
# Epoch  156 MSE:  0.0019938223995268345
# Epoch  157 MSE:  0.001976040191948414
# Epoch  158 MSE:  0.0019587241113185883
# Epoch  159 MSE:  0.0019419318996369839
# Epoch  160 MSE:  0.0019256517989560962
# Epoch  161 MSE:  0.0019099273486062884
# Epoch  162 MSE:  0.0018947473727166653
# Epoch  163 MSE:  0.0018801079131662846
# Epoch  164 MSE:  0.001865949248895049
# Epoch  165 MSE:  0.001852252520620823
# Epoch  166 MSE:  0.0018389516044408083
# Epoch  167 MSE:  0.0018259824719280005
# Epoch  168 MSE:  0.0018133028643205762
# Epoch  169 MSE:  0.0018008474726229906
# Epoch  170 MSE:  0.001788577064871788
# Epoch  171 MSE:  0.0017764560179784894
# Epoch  172 MSE:  0.0017644595354795456
# Epoch  173 MSE:  0.001752589363604784
# Epoch  174 MSE:  0.001740845968015492
# Epoch  175 MSE:  0.0017292383126914501
# Epoch  176 MSE:  0.001717790961265564
# Epoch  177 MSE:  0.0017065211432054639
# Epoch  178 MSE:  0.0016954458551481366
# Epoch  179 MSE:  0.0016845841892063618
# Epoch  180 MSE:  0.0016739448765292764
# Epoch  181 MSE:  0.0016635326901450753
# Epoch  182 MSE:  0.0016533532179892063
# Epoch  183 MSE:  0.0016434041317552328
# Epoch  184 MSE:  0.0016336776316165924
# Epoch  185 MSE:  0.0016241736011579633
# Epoch  186 MSE:  0.0016148826107382774
# Epoch  187 MSE:  0.001605797791853547
# Epoch  188 MSE:  0.0015969147207215428
# Epoch  189 MSE:  0.001588225131854415
# Epoch  190 MSE:  0.0015797266969457269
# Epoch  191 MSE:  0.0015714139444753528
# Epoch  192 MSE:  0.0015632841968908906
# Epoch  193 MSE:  0.0015553344273939729
# Epoch  194 MSE:  0.0015475647523999214
# Epoch  195 MSE:  0.0015399730764329433
# Epoch  196 MSE:  0.001532557886093855
# Epoch  197 MSE:  0.0015253216261044145
# Epoch  198 MSE:  0.0015182615024968982
# Epoch  199 MSE:  0.0015113783301785588

# %%
plt.plot(hist, label='Training Loss')
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_squared_error

y_train_pred = model(X_train)
y_test_pred = model(X_test)

y_train_pred = scaler.inverse_transform(y_train_pred.detach().numpy())
y_train = scaler.inverse_transform(y_train.detach().numpy())
y_test_pred = scaler.inverse_transform(y_test_pred.detach().numpy())
y_test = scaler.inverse_transform(y_test.detach().numpy())

trainScore = np.sqrt(mean_squared_error(y_train[:,0], y_train_pred[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = np.sqrt(mean_squared_error(y_test[:,0], y_test_pred[:,0]))
print('Test Score: %.2f RMSE' % (testScore))
# Out:
# Train Score: 2.17 RMSE
# Test Score: 2.11 RMSE

# %%
plt.figure(figsize=(20, 10))
plt.plot(testing_data['Date'], y_test, label='Closing Price')
plt.plot(testing_data['Date'], y_test_pred, label='Predicted Price')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()
