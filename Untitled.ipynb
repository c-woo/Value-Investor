# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from tensorflow.keras import models
from tensorflow.keras import layers
from sklearn.metrics import mean_squared_error

# %%
PAMP = pd.read_csv('./Data/Argentina - Pampa Energia SA (PAMP).csv')
BEEF = pd.read_csv('./Data/Brazil - Minerva SA_Brazil (BEEF3).csv')
CCB = pd.read_csv('./Data/Colombia - Cementos Argos SA (CCB).csv')
MNHD = pd.read_csv('./Data/Egypt - Medinet Nasr Housing (MNHD).csv')
SBER = pd.read_csv('./Data/Russia - Sberbank Rossii PAO (SBER).csv')
IMPJ = pd.read_csv('./Data/South Africa - Impala Platinum Holdings Ltd (IMPJ).csv')
DSMC = pd.read_csv('./Data/South Korea - Dongkuk Steel Mill Co Ltd (001230).csv')
KCHOL = pd.read_csv('./Data/Turkey - Koc Holding AS (KCHOL).csv')

# %%
PAMP
# Out:
#                 Date           Price                Open             High  \
# 0       Mar 31, 2021           85.15                86.5             88.1
# 1       Mar 30, 2021            86.1               85.15            86.75
# 2       Mar 29, 2021              85                  80               86
# 3       Mar 26, 2021           81.85                  84             84.6
# 4       Mar 25, 2021            83.6                85.2             87.3
# ..               ...             ...                 ...              ...
# 296     Jan 07, 2020            47.6               48.35               49
# 297     Jan 06, 2020            48.5                48.4             48.7
# 298     Jan 03, 2020            48.8               48.25            49.45
# 299     Jan 02, 2020           48.25               49.35             50.2
# 300  Highest: 90.000  Lowest: 32.000  Difference: 58.000  Average: 61.244
#
#                   Low     Vol. Change %
# 0               85.15  564.30K   -1.10%
# 1                84.6  141.40K    1.29%
# 2                  79  371.22K    3.85%
# 3                80.7  462.55K   -2.09%
# 4                82.1  389.78K   -3.13%
# ..                ...      ...      ...
# 296              46.9  901.95K   -1.86%
# 297                47  719.24K   -0.61%
# 298              46.5  595.36K    1.14%
# 299             47.55  878.50K   -2.92%
# 300  Change %: 71.328      NaN      NaN
#
# [301 rows x 7 columns]

# %%
PAMP.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      301 non-null    object
#  1   Price     301 non-null    object
#  2   Open      301 non-null    object
#  3   High      301 non-null    object
#  4   Low       301 non-null    object
#  5   Vol.      300 non-null    object
#  6   Change %  300 non-null    object
# dtypes: object(7)
# memory usage: 16.6+ KB

# %%
## drop last row because it doesn't contain relevant information

PAMP.drop(300, inplace=True)

# %%
## change date column to datetime

PAMP['Date'] = pd.to_datetime(PAMP['Date'], format='%b %d, %Y')

# %%
## change price columns to integer

PAMP['Price'] = pd.to_numeric(PAMP['Price'])
PAMP['Open'] = pd.to_numeric(PAMP['Open'])
PAMP['High'] = pd.to_numeric(PAMP['High'])
PAMP['Low'] = pd.to_numeric(PAMP['Low'])

# %%
PAMP.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 300 entries, 0 to 299
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      300 non-null    datetime64[ns]
#  1   Price     300 non-null    float64
#  2   Open      300 non-null    float64
#  3   High      300 non-null    float64
#  4   Low       300 non-null    float64
#  5   Vol.      300 non-null    object
#  6   Change %  300 non-null    object
# dtypes: datetime64[ns](1), float64(4), object(2)
# memory usage: 18.8+ KB

# %%
PAMP.sort_values(['Date'], ascending=True, ignore_index=True, inplace=True)
PAMP
# Out:
# 267 2021-02-10  84.40  86.00  86.00  83.20  397.81K   -1.29%
# 268 2021-02-11  83.30  84.30  85.50  82.60  158.50K   -1.30%
# 269 2021-02-12  85.20  82.10  85.25  82.10  456.75K    2.28%
# 270 2021-02-17  88.40  86.00  88.45  85.60  982.48K    3.76%
# 271 2021-02-18  85.40  89.00  90.00  83.90  368.91K   -3.39%
# 272 2021-02-19  85.50  86.00  86.80  84.00  638.73K    0.12%
# 273 2021-02-22  82.50  85.00  85.00  81.70  504.38K   -3.51%
# 274 2021-02-23  81.40  84.50  84.50  78.70  193.85K   -1.33%
# 275 2021-02-24  82.00  81.00  83.45  81.00  353.11K    0.74%
# 276 2021-02-25  79.00  82.10  84.00  73.90  419.18K   -3.66%
# 277 2021-02-26  77.80  78.30  82.45  77.70  304.86K   -1.52%
# 278 2021-03-01  80.00  78.00  80.90  78.00  346.72K    2.83%
# 279 2021-03-02  79.50  80.00  82.70  78.65  448.27K   -0.63%
# 280 2021-03-03  79.20  79.50  81.00  77.50  518.73K   -0.38%
# 281 2021-03-04  82.00  78.00  83.90  78.00  627.01K    3.54%
# 282 2021-03-05  82.50  81.80  82.80  77.00  383.65K    0.61%
# 283 2021-03-08  80.70  82.00  83.00  80.20  374.94K   -2.18%
# 284 2021-03-09  82.00  80.50  82.50  80.20  419.69K    1.61%
# 285 2021-03-10  82.50  82.00  82.90  80.80  684.70K    0.61%
# 286 2021-03-11  84.00  82.50  84.30  82.50  391.04K    1.82%
# 287 2021-03-12  86.60  82.00  87.25  82.00  596.87K    3.10%
# 288 2021-03-15  88.20  86.80  89.00  86.70  623.81K    1.85%
# 289 2021-03-16  87.70  87.05  89.45  86.80  560.40K   -0.57%
# 290 2021-03-17  88.50  87.00  88.60  86.00  308.27K    0.91%
# 291 2021-03-18  88.00  88.45  88.95  86.50  494.07K   -0.56%
# 292 2021-03-19  88.15  87.00  88.85  86.05  355.16K    0.17%
# 293 2021-03-22  88.90  87.00  89.00  86.70  389.38K    0.85%
# 294 2021-03-23  86.30  88.00  88.95  86.30  368.87K   -2.92%
# 295 2021-03-25  83.60  85.20  87.30  82.10  389.78K   -3.13%
# 296 2021-03-26  81.85  84.00  84.60  80.70  462.55K   -2.09%
# 297 2021-03-29  85.00  80.00  86.00  79.00  371.22K    3.85%
# 298 2021-03-30  86.10  85.15  86.75  84.60  141.40K    1.29%
# 299 2021-03-31  85.15  86.50  88.10  85.15  564.30K   -1.10%

# %%
## split training data and testing data, testing data will be the year of 2021

training_data = PAMP[['Date', 'Price']][:240]
testing_data = PAMP[['Date', 'Price']][240:]

# %% [markdown]
# ## Daily

# %%
def get_train_data(data, window_size):
    
    X, y = [], []
    
    for i in range(window_size, len(data)):
        X.append(data[i-window_size:i])
        y.append(data[i])
    
    return np.array(X), np.array(y)

# %%
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(PAMP[['Price']])
scaled_train_data = scaled_data[:240]

# %%
X_train, y_train = get_train_data(scaled_train_data, 10)

# %%
inputs = tf.keras.Input(shape=(X_train.shape[1], 1))
x = layers.LSTM(units=50, return_sequences=True)(inputs)
x = layers.Dropout(0.2)(x)
x = layers.LSTM(units=50)(x)
x = layers.Dropout(0.2)(x)
output = layers.Dense(1, activation='linear')(x)

model = tf.keras.Model(inputs=inputs, outputs=output)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 10, 1)]           0
#
#  lstm (LSTM)                 (None, 10, 50)            10400
#
#  dropout (Dropout)           (None, 10, 50)            0
#
#  lstm_1 (LSTM)               (None, 50)                20200
#
#  dropout_1 (Dropout)         (None, 50)                0
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 30,651
# Trainable params: 30,651
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='mean_squared_error', 
              optimizer=tf.keras.optimizers.Adam(lr=.01, decay=0.01))

history = model.fit(X_train, y_train, epochs=200)
# Out:
# Epoch 1/200
# C:\Users\Chris\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# 8/8 [==============================] - 3s 11ms/step - loss: 0.1451
# Epoch 2/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0624
# Epoch 3/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0346
# Epoch 4/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0179
# Epoch 5/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0109
# Epoch 6/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0074
# Epoch 7/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0070
# Epoch 8/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0080
# Epoch 9/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0076
# Epoch 10/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0069
# Epoch 11/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0070
# Epoch 12/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0059
# Epoch 13/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0074
# Epoch 14/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0062
# Epoch 15/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0052
# Epoch 16/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0061
# Epoch 17/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0058
# Epoch 18/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0053
# Epoch 19/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0051
# Epoch 20/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0058
# Epoch 21/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0042
# Epoch 22/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0061
# Epoch 23/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0050
# Epoch 24/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0053
# Epoch 25/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0046
# Epoch 26/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0055
# Epoch 27/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0054
# Epoch 28/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0058
# Epoch 29/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0051
# Epoch 30/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0052
# Epoch 31/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0049
# Epoch 32/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0056
# Epoch 33/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0049
# Epoch 34/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0045
# Epoch 35/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0051
# Epoch 36/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0051
# Epoch 37/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0056
# Epoch 38/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0058
# Epoch 39/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0057
# Epoch 40/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0055
# Epoch 41/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0055
# Epoch 42/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0047
# Epoch 43/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0049
# Epoch 44/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0046
# Epoch 45/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0049
# Epoch 46/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0044
# Epoch 47/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0046
# Epoch 48/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0043
# Epoch 49/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0046
# Epoch 50/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0046
# Epoch 51/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0048
# Epoch 52/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0040
# Epoch 53/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0040
# Epoch 54/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0039
# Epoch 55/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0047
# Epoch 56/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0050
# Epoch 57/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0041
# Epoch 58/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0042
# Epoch 59/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0043
# Epoch 60/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0046
# Epoch 61/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0042
# Epoch 62/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0040
# Epoch 63/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0045
# Epoch 64/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0046
# Epoch 65/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0044
# Epoch 66/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0040
# Epoch 67/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0047
# Epoch 68/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0038
# Epoch 69/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0042
# Epoch 70/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0043
# Epoch 71/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0031
# Epoch 72/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0039
# Epoch 73/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0039
# Epoch 74/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0036
# Epoch 75/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0049
# Epoch 76/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0042
# Epoch 77/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0039
# Epoch 78/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0039
# Epoch 79/200
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0040
# Epoch 80/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0041
# Epoch 81/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0040
# Epoch 82/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0034
# Epoch 83/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0041
# Epoch 84/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0045
# Epoch 85/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0041
# Epoch 86/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0036
# Epoch 87/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0039
# Epoch 88/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0038
# Epoch 89/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0035
# Epoch 90/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0041
# Epoch 91/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0039
# Epoch 92/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0035
# Epoch 93/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0040
# Epoch 94/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0037
# Epoch 95/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0034
# Epoch 96/200
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0033
# Epoch 97/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0034
# Epoch 98/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0034
# Epoch 99/200
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0037
# Epoch 100/200
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0042
# Epoch 101/200
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0038
# Epoch 102/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0036
# Epoch 103/200
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0042
# Epoch 104/200
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0037
# Epoch 105/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0048
# Epoch 106/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0040
# Epoch 107/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0037
# Epoch 108/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0032
# Epoch 109/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0037
# Epoch 110/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0035
# Epoch 111/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0034
# Epoch 112/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0034
# Epoch 113/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0037
# Epoch 114/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0035
# Epoch 115/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0031
# Epoch 116/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0041
# Epoch 117/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0036
# Epoch 118/200
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0031
# Epoch 119/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0033
# Epoch 120/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0032
# Epoch 121/200
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0036
# Epoch 122/200
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0034
# Epoch 123/200
# 8/8 [==============================] - 0s 13ms/step - loss: 0.0036
# Epoch 124/200
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0032
# Epoch 125/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0037
# Epoch 126/200
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0032
# Epoch 127/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0038
# Epoch 128/200
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0041
# Epoch 129/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0038
# Epoch 130/200
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0039
# Epoch 131/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0035
# Epoch 132/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0035
# Epoch 133/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0031
# Epoch 134/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0032
# Epoch 135/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0036
# Epoch 136/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0033
# Epoch 137/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0034
# Epoch 138/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0033
# Epoch 139/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0030
# Epoch 140/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0031
# Epoch 141/200
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0038
# Epoch 142/200
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0031
# Epoch 143/200
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0030
# Epoch 144/200
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0037
# Epoch 145/200
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0035
# Epoch 146/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0028
# Epoch 147/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0038
# Epoch 148/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0040
# Epoch 149/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0030
# Epoch 150/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0034
# Epoch 151/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0033
# Epoch 152/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0033
# Epoch 153/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0030
# Epoch 154/200
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0036
# Epoch 155/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0031
# Epoch 156/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0034
# Epoch 157/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0037
# Epoch 158/200
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0029
# Epoch 159/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0030
# Epoch 160/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0032
# Epoch 161/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0030
# Epoch 162/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0031
# Epoch 163/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0034
# Epoch 164/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0030
# Epoch 165/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0030
# Epoch 166/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0034
# Epoch 167/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0033
# Epoch 168/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0030
# Epoch 169/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0032
# Epoch 170/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0034
# Epoch 171/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0031
# Epoch 172/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0029
# Epoch 173/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0030
# Epoch 174/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0026
# Epoch 175/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0033
# Epoch 176/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0031
# Epoch 177/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0026
# Epoch 178/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0029
# Epoch 179/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0031
# Epoch 180/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0029
# Epoch 181/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0028
# Epoch 182/200
# 8/8 [==============================] - 0s 21ms/step - loss: 0.0034
# Epoch 183/200
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0025
# Epoch 184/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0032
# Epoch 185/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0025
# Epoch 186/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0026
# Epoch 187/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0031
# Epoch 188/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0030
# Epoch 189/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0033
# Epoch 190/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0030
# Epoch 191/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0028
# Epoch 192/200
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0031
# Epoch 193/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0036
# Epoch 194/200
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0030
# Epoch 195/200
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0026
# Epoch 196/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0032
# Epoch 197/200
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0031
# Epoch 198/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0032
# Epoch 199/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0029
# Epoch 200/200
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0028

# %%
plt.figure(figsize=(10, 8))
plt.plot(history.history['loss'], label='training loss')

# %%
def get_test_data(data, scaler, window_size):
    raw = data['Price'][len(data) - len(testing_data) - window_size:].values
    raw = raw.reshape(-1, 1)
    raw = scaler.transform(raw)
    
    X_test = []
    
    for i in range(window_size, raw.shape[0]):
        X_test.append(raw[i-window_size:i, 0])
        
    X_test = np.array(X_test)
    
    X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
    
    return X_test

# %%
X_test = get_test_data(PAMP, scaler, 10)

# %%
y_test = []

for i in range(240, len(PAMP)):
    y_test.append(PAMP['Price'][i])
    
y_test = np.array(y_test)

# %%
y_test.reshape(-1, 1)
# Out:
# array([[76.7 ],
#        [78.3 ],
#        [78.  ],
#        [79.95],
#        [79.  ],
#        [75.5 ],
#        [76.  ],
#        [77.5 ],
#        [77.  ],
#        [78.1 ],
#        [77.5 ],
#        [78.8 ],
#        [80.5 ],
#        [76.3 ],
#        [74.8 ],
#        [75.  ],
#        [80.2 ],
#        [80.6 ],
#        [83.  ],
#        [79.  ],
#        [81.  ],
#        [80.6 ],
#        [80.  ],
#        [83.65],
#        [84.5 ],
#        [85.  ],
#        [85.5 ],
#        [84.4 ],
#        [83.3 ],
#        [85.2 ],
#        [88.4 ],
#        [85.4 ],
#        [85.5 ],
#        [82.5 ],
#        [81.4 ],
#        [82.  ],
#        [79.  ],
#        [77.8 ],
#        [80.  ],
#        [79.5 ],
#        [79.2 ],
#        [82.  ],
#        [82.5 ],
#        [80.7 ],
#        [82.  ],
#        [82.5 ],
#        [84.  ],
#        [86.6 ],
#        [88.2 ],
#        [87.7 ],
#        [88.5 ],
#        [88.  ],
#        [88.15],
#        [88.9 ],
#        [86.3 ],
#        [83.6 ],
#        [81.85],
#        [85.  ],
#        [86.1 ],
#        [85.15]])

# %%
pred_price = model.predict(X_test)
pred_price = scaler.inverse_transform(pred_price)
testing_data['Predicted_Price'] = pred_price

# %%
plt.figure(figsize=(20, 10))

plt.plot(training_data['Date'], training_data['Price'], label='Training Price')
plt.plot(testing_data['Date'], testing_data['Price'], label='Testing Data')
plt.plot(testing_data['Date'], testing_data['Predicted_Price'], label='Predicted Price')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('PAMP Stock Price')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 10))
plt.plot(testing_data['Date'], testing_data['Price'], label='Closing Price')
plt.plot(testing_data['Date'], testing_data['Predicted_Price'], label='Predicted Price')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Daily Price of PAMP in 2021')
plt.legend()
plt.show()

# %% [markdown]
# Either have an output for the 7 days of the week or have an output and use previous day's prediction as well

# %% [markdown]
# ## Weekly

# %%
def get_weekly_train_data(data, window_size):
    
    X, y = [], []
    
    for i in range(window_size, len(data), 5):
        X.append(data[i-window_size:i])
        y.append(data[i:i+5])
    
    return np.array(X), np.array(y)

# %%
X_train_w, y_train_w = get_weekly_train_data(scaled_train_data, 10)

# %%
inputs = tf.keras.Input(shape=(X_train_w.shape[1], 1))
x = layers.LSTM(units=50, return_sequences=True)(inputs)
x = layers.Dropout(0.2)(x)
x = layers.LSTM(units=50)(x)
x = layers.Dropout(0.2)(x)
output = layers.Dense(5, activation='linear')(x)

model = tf.keras.Model(inputs=inputs, outputs=output)
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 10, 1)]           0
#
#  lstm_2 (LSTM)               (None, 10, 50)            10400
#
#  dropout_2 (Dropout)         (None, 10, 50)            0
#
#  lstm_3 (LSTM)               (None, 50)                20200
#
#  dropout_3 (Dropout)         (None, 50)                0
#
#  dense_1 (Dense)             (None, 5)                 255
#
# =================================================================
# Total params: 30,855
# Trainable params: 30,855
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='mean_squared_error', 
              optimizer=tf.keras.optimizers.Adam(lr=.01, decay=0.01))

history = model.fit(X_train_w, y_train_w, epochs=200)
# Out:
# Epoch 1/200
# C:\Users\Chris\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# 2/2 [==============================] - 3s 12ms/step - loss: 0.1846
# Epoch 2/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0493
# Epoch 3/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0384
# Epoch 4/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0285
# Epoch 5/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0118
# Epoch 6/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0180
# Epoch 7/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0152
# Epoch 8/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0113
# Epoch 9/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0162
# Epoch 10/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0106
# Epoch 11/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0113
# Epoch 12/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0114
# Epoch 13/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0114
# Epoch 14/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0096
# Epoch 15/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0117
# Epoch 16/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0098
# Epoch 17/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0115
# Epoch 18/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0099
# Epoch 19/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0148
# Epoch 20/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0100
# Epoch 21/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0101
# Epoch 22/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0094
# Epoch 23/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0086
# Epoch 24/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0080
# Epoch 25/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0076
# Epoch 26/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0116
# Epoch 27/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0090
# Epoch 28/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0081
# Epoch 29/200
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0081
# Epoch 30/200
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0110
# Epoch 31/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0103
# Epoch 32/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0094
# Epoch 33/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0085
# Epoch 34/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0094
# Epoch 35/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0089
# Epoch 36/200
# 2/2 [==============================] - 0s 14ms/step - loss: 0.0087
# Epoch 37/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0080
# Epoch 38/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0073
# Epoch 39/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0075
# Epoch 40/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0084
# Epoch 41/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0068
# Epoch 42/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0084
# Epoch 43/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0088
# Epoch 44/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0103
# Epoch 45/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0075
# Epoch 46/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0075
# Epoch 47/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0088
# Epoch 48/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0113
# Epoch 49/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0087
# Epoch 50/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0076
# Epoch 51/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0100
# Epoch 52/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0109
# Epoch 53/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0075
# Epoch 54/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0085
# Epoch 55/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0105
# Epoch 56/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0079
# Epoch 57/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0084
# Epoch 58/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0105
# Epoch 59/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0086
# Epoch 60/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0078
# Epoch 61/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0075
# Epoch 62/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0062
# Epoch 63/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0062
# Epoch 64/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0071
# Epoch 65/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0077
# Epoch 66/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0081
# Epoch 67/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0073
# Epoch 68/200
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0059
# Epoch 69/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0062
# Epoch 70/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0103
# Epoch 71/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0081
# Epoch 72/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0071
# Epoch 73/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0075
# Epoch 74/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0095
# Epoch 75/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0066
# Epoch 76/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0071
# Epoch 77/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0085
# Epoch 78/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0081
# Epoch 79/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0076
# Epoch 80/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0073
# Epoch 81/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0077
# Epoch 82/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0071
# Epoch 83/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0059
# Epoch 84/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0071
# Epoch 85/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0085
# Epoch 86/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0073
# Epoch 87/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0071
# Epoch 88/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0068
# Epoch 89/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0067
# Epoch 90/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0077
# Epoch 91/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0064
# Epoch 92/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0083
# Epoch 93/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0081
# Epoch 94/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0077
# Epoch 95/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0093
# Epoch 96/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0054
# Epoch 97/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0066
# Epoch 98/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0065
# Epoch 99/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0067
# Epoch 100/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0068
# Epoch 101/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0064
# Epoch 102/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0072
# Epoch 103/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0068
# Epoch 104/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0086
# Epoch 105/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0067
# Epoch 106/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0073
# Epoch 107/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0075
# Epoch 108/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0068
# Epoch 109/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0075
# Epoch 110/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0080
# Epoch 111/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0076
# Epoch 112/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0069
# Epoch 113/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0085
# Epoch 114/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0072
# Epoch 115/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0060
# Epoch 116/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0081
# Epoch 117/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0068
# Epoch 118/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0071
# Epoch 119/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0065
# Epoch 120/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0058
# Epoch 121/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0095
# Epoch 122/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0076
# Epoch 123/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0060
# Epoch 124/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0066
# Epoch 125/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0067
# Epoch 126/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0076
# Epoch 127/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0065
# Epoch 128/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0092
# Epoch 129/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0085
# Epoch 130/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0059
# Epoch 131/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0055
# Epoch 132/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0062
# Epoch 133/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0071
# Epoch 134/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0053
# Epoch 135/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0063
# Epoch 136/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0056
# Epoch 137/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0065
# Epoch 138/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0068
# Epoch 139/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0055
# Epoch 140/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0074
# Epoch 141/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0066
# Epoch 142/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0082
# Epoch 143/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0078
# Epoch 144/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0061
# Epoch 145/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0060
# Epoch 146/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0077
# Epoch 147/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0061
# Epoch 148/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0072
# Epoch 149/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0071
# Epoch 150/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0084
# Epoch 151/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0074
# Epoch 152/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0061
# Epoch 153/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0071
# Epoch 154/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0079
# Epoch 155/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0072
# Epoch 156/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0065
# Epoch 157/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0068
# Epoch 158/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0058
# Epoch 159/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0054
# Epoch 160/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0050
# Epoch 161/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0084
# Epoch 162/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0057
# Epoch 163/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0089
# Epoch 164/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0074
# Epoch 165/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0072
# Epoch 166/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0063
# Epoch 167/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0074
# Epoch 168/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0061
# Epoch 169/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0064
# Epoch 170/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0066
# Epoch 171/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0055
# Epoch 172/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0070
# Epoch 173/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0055
# Epoch 174/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0059
# Epoch 175/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0082
# Epoch 176/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0064
# Epoch 177/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0060
# Epoch 178/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0088
# Epoch 179/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0065
# Epoch 180/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0072
# Epoch 181/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0077
# Epoch 182/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0073
# Epoch 183/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0055
# Epoch 184/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0072
# Epoch 185/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0060
# Epoch 186/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0067
# Epoch 187/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0067
# Epoch 188/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0054
# Epoch 189/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0056
# Epoch 190/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0055
# Epoch 191/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0092
# Epoch 192/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0063
# Epoch 193/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0054
# Epoch 194/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0058
# Epoch 195/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0052
# Epoch 196/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0050
# Epoch 197/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0060
# Epoch 198/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0060
# Epoch 199/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0069
# Epoch 200/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0059

# %%
plt.figure(figsize=(10, 8))
plt.plot(history.history['loss'], label='training loss')

# %%
y_test_w = []

for i in range(240, len(PAMP), 5):
    y_test_w.append(PAMP['Price'][i:i+5])
    
y_test_w = np.array(y_test_w)

# %%
def get_weekly_test_data(data, scaler, window_size):
    raw = data['Price'][len(data) - len(testing_data) - window_size:].values
    raw = raw.reshape(-1, 1)
    raw = scaler.transform(raw)
    
    X_test = []
    
    for i in range(window_size, raw.shape[0], 5):
        X_test.append(raw[i-window_size:i, 0])
        
    X_test = np.array(X_test)
    
    X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
    
    return X_test

# %%
X_test_w = get_weekly_test_data(PAMP, scaler, 10)

# %%
pred_price = model.predict(X_test_w)
pred_price = scaler.inverse_transform(pred_price)

train_pred_price = model.predict(X_train_w)
train_pred_price = scaler.inverse_transform(train_pred_price)

# %%
trainScore = np.sqrt(mean_squared_error(scaler.inverse_transform(y_train_w[:,:,0]), train_pred_price))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = np.sqrt(mean_squared_error(y_test_w, pred_price))
print('Test Score: %.2f RMSE' % (testScore))
# Out:
# Train Score: 3.89 RMSE
# Test Score: 2.93 RMSE

# %%
plt.figure(figsize=(20, 10))

plt.plot(training_data['Date'], training_data['Price'], label='Training Price')
plt.plot(testing_data['Date'], testing_data['Price'], label='Testing Data')
plt.plot(testing_data['Date'], pred_price.flatten(), label='Predicted Price')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('PAMP Stock Price')
plt.legend()
plt.show()

# %% [markdown]
# ## PyTorch

# %%
import torch
import torch.nn as nn

# %%
def split_data(stock, lookback):
    data_raw = stock.to_numpy() # convert to numpy array
    data = []
    
    # create all possible sequences of length seq_len
    for index in range(len(data_raw) - lookback): 
        data.append(data_raw[index: index + lookback])

    data = np.array(data)
    test_set_size = 60
    train_set_size = data.shape[0] - (test_set_size)
    
    x_train = data[:train_set_size,:-1,:]
    y_train = data[:train_set_size,-1,:]
    
    x_test = data[train_set_size:,:-1]
    y_test = data[train_set_size:,-1,:]
    
    return [x_train, y_train, x_test, y_test]

# %%
price = PAMP[['Price']]
price['Price'] = scaler.transform(price['Price'].values.reshape(-1, 1))
price
# Out:
# C:\Users\Chris\AppData\Local\Temp/ipykernel_15008/3439380683.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   price['Price'] = scaler.transform(price['Price'].values.reshape(-1, 1))
#         Price
# 0    0.272809
# 1    0.282648
# 2    0.277281
# 3    0.261181
# 4    0.241503
# ..        ...
# 295  0.905188
# 296  0.873882
# 297  0.930233
# 298  0.949911
# 299  0.932916
#
# [300 rows x 1 columns]

# %%
X_train, y_train, X_test, y_test = split_data(price, 14)

# %%
X_train = np.array(X_train)
y_train = np.array(y_train)
X_test = np.array(X_test)
y_test = np.array(y_test)

# %%
X_train = torch.from_numpy(X_train).type(torch.Tensor)
X_test = torch.from_numpy(X_test).type(torch.Tensor)
y_train = torch.from_numpy(y_train).type(torch.Tensor)
y_test = torch.from_numpy(y_test).type(torch.Tensor)

# %%
class LSTM(nn.Module):
    def __init__(self, input_dim, hidden_dim, num_layers, output_dim):
        super(LSTM, self).__init__()
        self.hidden_dim = hidden_dim
        self.num_layers = num_layers
        
        self.lstm = nn.LSTM(input_dim, hidden_dim, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_dim, output_dim)   
        
    def forward(self, x):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_dim).requires_grad_()
        c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_dim).requires_grad_()
        out, (hn, cn) = self.lstm(x, (h0.detach(), c0.detach()))
        out = self.fc(out[:, -1, :]) 
        return out

# %%
model = LSTM(input_dim=1, hidden_dim=50, output_dim=1, num_layers=2)
criterion = torch.nn.MSELoss(reduction='mean')
optimiser = torch.optim.Adam(model.parameters(), lr=0.01)

# %%
print(model)
# Out:
# LSTM(
#   (lstm): LSTM(1, 50, num_layers=2, batch_first=True)
#   (fc): Linear(in_features=50, out_features=1, bias=True)
# )

# %%
num_epochs = 200

hist = np.zeros(num_epochs)
lstm = []
for t in range(num_epochs):
    y_train_pred = model(X_train)    
    
    loss = criterion(y_train_pred, y_train)
    print("Epoch ", t, "MSE: ", loss.item())
    hist[t] = loss.item()    
    
    optimiser.zero_grad()
    loss.backward()
    optimiser.step()
# Out:
# Epoch  0 MSE:  0.1936083734035492
# Epoch  1 MSE:  0.07280280441045761
# Epoch  2 MSE:  0.1601894497871399
# Epoch  3 MSE:  0.06152667477726936
# Epoch  4 MSE:  0.06680075824260712
# Epoch  5 MSE:  0.08011002093553543
# Epoch  6 MSE:  0.08489563316106796
# Epoch  7 MSE:  0.08246768265962601
# Epoch  8 MSE:  0.07568779587745667
# Epoch  9 MSE:  0.0668138712644577
# Epoch  10 MSE:  0.05780792608857155
# Epoch  11 MSE:  0.051033709198236465
# Epoch  12 MSE:  0.0495532751083374
# Epoch  13 MSE:  0.05395178496837616
# Epoch  14 MSE:  0.055670615285634995
# Epoch  15 MSE:  0.049985915422439575
# Epoch  16 MSE:  0.04264334961771965
# Epoch  152 MSE:  0.002217401284724474
# Epoch  153 MSE:  0.0022078319452703
# Epoch  154 MSE:  0.0021981620229780674
# Epoch  155 MSE:  0.0021883188746869564
# Epoch  156 MSE:  0.002178233116865158
# Epoch  157 MSE:  0.0021679264027625322
# Epoch  158 MSE:  0.002157351700589061
# Epoch  159 MSE:  0.0021465993486344814
# Epoch  160 MSE:  0.0021356362849473953
# Epoch  161 MSE:  0.002124585211277008
# Epoch  162 MSE:  0.0021134575363248587
# Epoch  163 MSE:  0.0021023305598646402
# Epoch  164 MSE:  0.0020912240725010633
# Epoch  165 MSE:  0.002080204663798213
# Epoch  166 MSE:  0.00206929724663496
# Epoch  167 MSE:  0.0020585062447935343
# Epoch  168 MSE:  0.0020478488877415657
# Epoch  169 MSE:  0.002037324942648411
# Epoch  170 MSE:  0.0020269432570785284
# Epoch  171 MSE:  0.0020166742615401745
# Epoch  172 MSE:  0.0020065258722752333
# Epoch  173 MSE:  0.0019964787643402815
# Epoch  174 MSE:  0.0019865354988723993
# Epoch  175 MSE:  0.001976671861484647
# Epoch  176 MSE:  0.001966895768418908
# Epoch  177 MSE:  0.001957198139280081
# Epoch  178 MSE:  0.0019475840963423252
# Epoch  179 MSE:  0.0019380435114726424
# Epoch  180 MSE:  0.0019285911694169044
# Epoch  181 MSE:  0.0019192295148968697
# Epoch  182 MSE:  0.0019099677447229624
# Epoch  183 MSE:  0.0019008080707862973
# Epoch  184 MSE:  0.001891769003123045
# Epoch  185 MSE:  0.0018828610191121697
# Epoch  186 MSE:  0.0018740983214229345
# Epoch  187 MSE:  0.0018654920859262347
# Epoch  188 MSE:  0.0018570616375654936
# Epoch  189 MSE:  0.0018488242058083415
# Epoch  190 MSE:  0.0018407924799248576
# Epoch  191 MSE:  0.0018329803133383393
# Epoch  192 MSE:  0.0018254007445648313
# Epoch  193 MSE:  0.0018180635524913669
# Epoch  194 MSE:  0.0018109711818397045
# Epoch  195 MSE:  0.00180412910412997
# Epoch  196 MSE:  0.001797533011995256
# Epoch  197 MSE:  0.0017911788308992982
# Epoch  198 MSE:  0.0017850549193099141
# Epoch  199 MSE:  0.0017791481222957373

# %%
plt.plot(hist, label='Training Loss')
plt.legend()
plt.show()

# %%
y_test = y_test.reshape(-1, 1)

# %%
y_train_pred = model(X_train)
y_test_pred = model(X_test)

y_train_pred = scaler.inverse_transform(y_train_pred.detach().numpy())
y_train = scaler.inverse_transform(y_train.detach().numpy())
y_test_pred = scaler.inverse_transform(y_test_pred.detach().numpy())
y_test = scaler.inverse_transform(y_test.detach().numpy())

trainScore = np.sqrt(mean_squared_error(y_train[:,0], y_train_pred[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = np.sqrt(mean_squared_error(y_test[:,0], y_test_pred[:,0]))
print('Test Score: %.2f RMSE' % (testScore))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15008/3988317132.py in <module>
#       3
#       4 y_train_pred = scaler.inverse_transform(y_train_pred.detach().numpy())
# ----> 5 y_train = scaler.inverse_transform(y_train.detach().numpy())
#       6 y_test_pred = scaler.inverse_transform(y_test_pred.detach().numpy())
#       7 y_test = scaler.inverse_transform(y_test.detach().numpy())
#
# AttributeError: 'numpy.ndarray' object has no attribute 'detach'

# %%
plt.figure(figsize=(20, 10))
plt.plot(testing_data['Date'], y_test, label='Closing Price')
plt.plot(testing_data['Date'], y_test_pred, label='Predicted Price')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15008/4180021113.py in <module>
#       1 plt.figure(figsize=(20, 10))
#       2 plt.plot(testing_data['Date'], y_test, label='Closing Price')
# ----> 3 plt.plot(testing_data['Date'], y_test_pred, label='Predicted Price')
#       4 plt.xlabel('Date')
#       5 plt.ylabel('Price')
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    3017 @_copy_docstring_and_deprecators(Axes.plot)
#    3018 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 3019     return gca().plot(
#    3020         *args, scalex=scalex, scaley=scaley,
#    3021         **({"data": data} if data is not None else {}), **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1605         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1606         for line in lines:
# -> 1607             self.add_line(line)
#    1608         self._request_autoscale_view(scalex=scalex, scaley=scaley)
#    1609         return lines
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py in add_line(self, line)
#    2099             line.set_clip_path(self.patch)
#    2100
# -> 2101         self._update_line_limits(line)
#    2102         if not line.get_label():
#    2103             line.set_label('_line%d' % len(self.lines))
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py in _update_line_limits(self, line)
#    2121         Figures out the data limit of the given line, updating self.dataLim.
#    2122         """
# -> 2123         path = line.get_path()
#    2124         if path.vertices.size == 0:
#    2125             return
#
# ~\anaconda3\lib\site-packages\matplotlib\lines.py in get_path(self)
#    1020         """
#    1021         if self._invalidy or self._invalidx:
# -> 1022             self.recache()
#    1023         return self._path
#    1024
#
# ~\anaconda3\lib\site-packages\matplotlib\lines.py in recache(self, always)
#     666         if always or self._invalidy:
#     667             yconv = self.convert_yunits(self._yorig)
# --> 668             y = _to_unmasked_float_array(yconv).ravel()
#     669         else:
#     670             y = self._y
#
# ~\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py in _to_unmasked_float_array(x)
#    1331         return np.ma.asarray(x, float).filled(np.nan)
#    1332     else:
# -> 1333         return np.asarray(x, float)
#    1334
#    1335
#
# ~\anaconda3\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order, like)
#     100         return _asarray_with_like(a, dtype=dtype, order=order, like=like)
#     101
# --> 102     return array(a, dtype, copy=False, order=order)
#     103
#     104
#
# ~\anaconda3\lib\site-packages\torch\_tensor.py in __array__(self, dtype)
#     678             return self.numpy()
#     679         else:
# --> 680             return self.numpy().astype(dtype, copy=False)
#     681
#     682     # Wrap Numpy array again in a suitable tensor when done, to support e.g.
#
# RuntimeError: Can't call numpy() on Tensor that requires grad. Use tensor.detach().numpy() instead.

# %% [markdown]
# ## Weekly

# %%
model = LSTM(input_dim=1, hidden_dim=50, output_dim=5, num_layers=2)
criterion = torch.nn.MSELoss(reduction='mean')
optimiser = torch.optim.Adam(model.parameters(), lr=0.01)

print(model)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15008/2250835367.py in <module>
# ----> 1 model = LSTM(input_dim=1, hidden_dim=50, output_dim=5, num_layers=2)
#       2 criterion = torch.nn.MSELoss(reduction='mean')
#       3 optimiser = torch.optim.Adam(model.parameters(), lr=0.01)
#       4
#       5 print(model)
#
# NameError: name 'LSTM' is not defined

# %%
num_epochs = 200

hist = np.zeros(num_epochs)
lstm = []
for t in range(num_epochs):
    y_train_pred = model(X_train)    
    
    loss = criterion(y_train_pred, y_train)
    print("Epoch ", t, "MSE: ", loss.item())
    hist[t] = loss.item()    
    
    optimiser.zero_grad()
    loss.backward()
    optimiser.step()

# %%
plt.plot(hist, label='Training Loss')
plt.legend()
plt.show()

# %%
y_train_pred = model(X_train)
y_test_pred = model(X_test)

y_train_pred = scaler.inverse_transform(y_train_pred.detach().numpy())
y_train = scaler.inverse_transform(y_train.detach().numpy())
y_test_pred = scaler.inverse_transform(y_test_pred.detach().numpy())
y_test = scaler.inverse_transform(y_test.detach().numpy())

trainScore = np.sqrt(mean_squared_error(y_train[:,0], y_train_pred[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = np.sqrt(mean_squared_error(y_test[:,0], y_test_pred[:,0]))
print('Test Score: %.2f RMSE' % (testScore))
